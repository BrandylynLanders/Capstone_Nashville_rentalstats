# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
#load the rental data
rental_data = pd.read_csv(r"C:\Users\brand\Documents\DA8\Projects\capstone_nashville_da8\data\Zillow_Metro_zori_sm_month.csv")

# %%
gdp_data.head()
# Out:
#          DATE   NGMP34980
# 0  2018-01-01  134391.666
# 1  2019-01-01  142709.378
# 2  2020-01-01  141966.618
# 3  2021-01-01  163031.737

# %%
short_term_rental_data.head()
# Out:
#      Permit #                     Applicant                       Contact  \
# 0  2022052402           Avery Owner 305 LLC          Stay Local Nashville
# 1  2022028676  WOLF, BRIAN  & ANNA MECHLING  WOLF, BRIAN  & ANNA MECHLING
# 2   201526366   Uhl, Thomas W. & Juanita M.                    Nieves Uhl
# 3   201528484       Schoenbrodt, Christa M.       Schoenbrodt, Christa M.
# 4  2021041773               BLAIN, DONNA L.            149 Bonita Parkway
#
#                Permit Subtype Description Permit Status          Parcel  \
# 0         Short Term Rental � Multifamily        ISSUED  061030E30100CO
# 1         Short Term Rental � Multifamily        ISSUED  091024Y30300CO
# 2  Short Term Rental - Non-Owner Occupied        ISSUED     07301018000
# 3      Short Term Rental - Owner Occupied        ISSUED     10408036300
# 4         Short Term Rental � Multifamily        ISSUED  092100M01700CO
#
#              Date Entered             Date Issued         Expiration Date  \
# ...

# %%
#overview of data structure
zip_codes_geojson.head()
# Out:
#   zipcode          poname  created_date objectid  \
# 0   37015    ASHLAND CITY           NaN       21
# 1   37143          PEGRAM           NaN       23
# 2   37072  GOODLETTSVILLE           NaN       46
# 3   37189    WHITES CREEK           NaN       50
# 4   37015    ASHLAND CITY           NaN       20
#
#                                  globalid  created_user  last_edited_date  \
# 0  {2AB8F204-63EE-49A4-A806-8E1DAE1C32AA}           NaN               NaN
# 1  {B142BE7A-6E4F-4325-95C5-A1C980D46F37}           NaN               NaN
# 2  {FD866D5C-A196-4C6E-9CFF-A04FD08B1657}           NaN               NaN
# 3  {AD8029C0-DF92-4103-B4DF-A67EF4F502E1}           NaN               NaN
# 4  {49D81E1C-5F08-414E-AED7-8C8F9714DD83}           NaN               NaN
#
#    last_edited_user                                           geometry
# 0               NaN  MULTIPOLYGON (((-86.88867 36.28013, -86.88867 ...
# 1               NaN  MULTIPOLYGON (((-87.03553 36.08659, -87.03556 ...
# ...

# %%
#overview of data structure
zip_codes_geojson.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   zipcode           57 non-null     object
#  1   poname            57 non-null     object
#  2   created_date      0 non-null      float64
#  3   objectid          57 non-null     object
#  4   globalid          57 non-null     object
#  5   created_user      0 non-null      float64
#  6   last_edited_date  0 non-null      float64
#  7   last_edited_user  0 non-null      float64
#  8   geometry          57 non-null     geometry
# dtypes: float64(4), geometry(1), object(4)
# memory usage: 4.1+ KB

# %%
df_gdp = pd.read_csv('C:/Users/brand/Documents/DA8/Projects/capstone_nashville_da8/data/GDPALL47037.csv')

# %%
#Load the GDP data
gdp_data = pd.read_csv(r"C:\Users\brand\Documents\DA8\Projects\capstone_nashville_da8\data\FRED TGDP for Nashville_18_21.csv")

# %%
df_rental = pd.read_csv('C:/Users/brand/Documents/DA8/Projects/capstone_nashville_da8/data/avg_monthly_rent.csv')

# %%
#Load the short-term rental permit data
short_term_rental_data = pd.read_csv(r"C:\Users\brand\Documents\DA8\Projects\capstone_nashville_da8\data\Residential_Short_Term_Rental_Permits (1).csv")

# %%
df_rental.head()
# Out:
#          Date     Avg Rent
# 14 2015-01-01  1201.659269
# 15 2016-01-01  1251.657210
# 16 2017-01-01  1311.570361
# 17 2018-01-01  1356.168629
# 18 2019-01-01  1406.719724

# %%
#load the rvac rates for nashville
tn_rvac = pd.read_csv(r"C:\Users\brand\Documents\DA8\Projects\capstone_nashville_da8\data\TNRVAC.csv")

# %%
df_gdp.head()
# Out:
#          Date       GDP
# 14 2015-01-01  60832960
# 15 2016-01-01  63608592
# 16 2017-01-01  66939774
# 17 2018-01-01  70872833
# 18 2019-01-01  75617629

# %%
#load the zip code csv
zip_codes_csv = pd.read_csv(r"C:\Users\brand\Documents\DA8\Projects\capstone_nashville_da8\data\Zip_Codes.csv")

# %%
#convert date column 
df_gdp['Date'] = pd.to_datetime(df_gdp['Date'], format='%Y/%m/%d')
df_rental['Date'] = pd.to_datetime(df_rental['Date'], format='%Y/%m/%d')

# %%
#load the zip geojson
zip_codes_geojson = gpd.read_file(r"C:\Users\brand\Documents\DA8\Projects\capstone_nashville_da8\data\Zip Codes (1).geojson")

# %%
#filter to 2015 to 2021
df_gdp = df_gdp[df_gdp['Date'].dt.year.between(2015, 2021)]
df_gdp = df_gdp[['Date', 'GDP']]

df_rental = df_rental[df_rental['Date'].dt.year.between(2015, 2021)]
df_rental = df_rental[['Date', 'Avg Rent']]

# %%
rental_data.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName   2015-03-31  \
# 0    102001         0    United States    country       NaN  1316.882137
# 1    394913         1     New York, NY        msa        NY  2443.764214
# 2    753899         2  Los Angeles, CA        msa        CA  1921.951938
# 3    394463         3      Chicago, IL        msa        IL  1490.453763
# 4    394514         4       Dallas, TX        msa        TX  1156.562026
#
#     2015-04-30   2015-05-31   2015-06-30   2015-07-31  ...   2022-07-31  \
# 0  1327.077746  1336.985344  1347.189723  1353.394167  ...  1987.491300
# 1  2464.719370  2483.196870  2500.971887  2512.718350  ...  3207.491920
# 2  1935.567889  1948.902894  1961.209437  1978.339689  ...  2916.787977
# 3  1502.135150  1513.653098  1523.141742  1529.525405  ...  1926.675734
# 4  1167.566988  1178.805865  1187.481860  1193.257396  ...  1822.737036
#
#     2022-08-31   2022-09-30   2022-10-31   2022-11-30   2022-12-31  \
# ...

# %%
#visualize the geoframe
zip_codes_geojson.plot()
# Out:
# <Axes: >

# %%
print(zip_codes_geojson.head())
# Out:
#   zipcode          poname  created_date objectid  \
# 0   37015    ASHLAND CITY           NaN       21
# 1   37143          PEGRAM           NaN       23
# 2   37072  GOODLETTSVILLE           NaN       46
# 3   37189    WHITES CREEK           NaN       50
# 4   37015    ASHLAND CITY           NaN       20
#
#                                  globalid  created_user  last_edited_date  \
# 0  {2AB8F204-63EE-49A4-A806-8E1DAE1C32AA}           NaN               NaN
# 1  {B142BE7A-6E4F-4325-95C5-A1C980D46F37}           NaN               NaN
# 2  {FD866D5C-A196-4C6E-9CFF-A04FD08B1657}           NaN               NaN
# 3  {AD8029C0-DF92-4103-B4DF-A67EF4F502E1}           NaN               NaN
# 4  {49D81E1C-5F08-414E-AED7-8C8F9714DD83}           NaN               NaN
#
#    last_edited_user                                           geometry
# 0               NaN  MULTIPOLYGON (((-86.88867 36.28013, -86.88867 ...
# 1               NaN  MULTIPOLYGON (((-87.03553 36.08659, -87.03556 ...
# ...

# %%
#zipcode boundaries
zip_codes_geojson.plot()
plt.show()

# %%
#central area
selected_zip_codes = zip_codes_geojson[zip_codes_geojson['zipcode'].isin(['37203', '37212'])]
selected_zip_codes.plot(column='zipcode', cmap='Set3', legend=True)
plt.show()

# %%
zip_codes_geojson.plot(column='zipcode', cmap='Set3', legend=True)
plt.show()
